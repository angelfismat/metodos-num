# %%
import numpy as np
import math
import rogues as rg

import matplotlib.pyplot as plt

# %%
def steep(Av,x,b,kmax=1e3,tol=1.0e-9):
    r = b - Av(x)
    s = r.copy()
    y = np.copy(x)
    k = 1
    for i in range(int(kmax)):
        u = Av(s)
        alpha = np.dot(s.T,r)/np.dot(s.T,u)
        x = x + alpha*r
        r = r - alpha*u
        y = np.hstack([y,x])
        k += 1
        if(math.sqrt(np.dot(r.T,r))) < tol:
            break
        s = r.copy()
    return x, k, y

# %%
A=np.array([[3.,2.],[2.,6.]])    
b=np.array([[5.],[8.]])
x=np.array([[0.],[.0]])

def Av(x):
    return A@x
    
x,k,y=steep(Av,x,b,tol=1.0e-9)

print("sol=",x)
print("iter=",k)
# Out:
# sol= [[1.]
#  [1.]]
# iter= 12

# %%
plt.plot(y[0,:],y[1,:]);plt.axis('equal');plt.grid();

# %%
A=rg.prolate(30)    
b=A@np.ones((30,1))
x0=np.zeros((30,1))
##
def Av(x):
    return A@x
##    
x,i,y = steep(Av,x0,b,tol=1.0e-9,kmax=1e5)
##

print("condicion=",np.linalg.cond(A))
print("sol=",x)
print("error=",np.linalg.norm(x-np.ones((30,1)))/np.linalg.norm(np.ones((30,1))))
print("iter=",i)
##
# Out:
# condicion= 3.6438542708257816e+16
# sol= [[0.99996386]
#  [1.00014795]
#  [0.99970317]
#  [1.00033963]
#  [0.9998296 ]
#  [0.99989753]
#  [1.00021757]
#  [0.99993492]
#  [0.99985235]
#  [1.00014362]
#  [1.00005624]
#  [0.99983745]
#  [1.00002795]
#  [1.00014275]
#  [0.99990418]
#  [0.99990418]
#  [1.00014275]
#  [1.00002795]
#  [0.99983745]
#  [1.00005624]
#  [1.00014362]
#  [0.99985235]
#  [0.99993492]
#  [1.00021757]
#  [0.99989753]
#  [0.9998296 ]
#  [1.00033963]
#  [0.99970317]
#  [1.00014795]
#  [0.99996386]]
# error= 0.00016735520264738628
# iter= 100001
